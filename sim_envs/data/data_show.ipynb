# %%
import numpy as np
import os

DATA_DIR_PATH = "/home/ubuntu/ysh/Code/SurEnv/sim_envs/data"

# %%
data = np.load(os.path.join(DATA_DIR_PATH, "demo/GoalNeedlePick-v0_200/0004/data.npz"))

# %%
print(data.keys())
print(data['observation.observation'].shape)
print(data["observation.achieved_goal"].shape)
print(data["observation.desired_goal"].shape)
print(data['action'].shape)
# Out:
# KeysView(NpzFile '/home/ubuntu/ysh/Code/SurEnv/sim_envs/data/demo/GoalNeedlePick-v0_200/0004/data.npz' with keys: observation.observation, observation.achieved_goal, observation.desired_goal, info.is_success, info.distance...)
# (34, 19)
# (34, 3)
# (34, 3)
# (34, 5)

# %%
action = data['action']
